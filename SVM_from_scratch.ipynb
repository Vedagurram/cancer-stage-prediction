# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from matplotlib import style
style.use('ggplot')

# %%
class Support_Vector_Machine:
    # def is the first method or function that will run when we call SVM function:-
    def __init__(self, visualization=True):
        self.visualization = visualization
        self.colors = {1:'r', -1:'b'}  # 1 class will be in red and -1 in blue color
        if self.visualization:
            self.fig = plt.figure()
            self.ax = self.fig.add_subplot(1,1,1)
            
            # training the data
            def fit(self, data):
                self.data = data
                # opt_dict is basically a dictionary --> {||W|| : [w,b]}
                opt_dict = {}
                
                transforms = [[1,1],  # transforms will be applied to vector of W 
                             [-1,1],
                             [1,-1],
                             [-1,-1]]
                
                all_data = []
                for yi in self.data:
                    for featureset in self.data[yi]:
                        for feature in featureset:
                            all_data.append(feature)
                            
                slef.max_feature_value = max(all_data)
                slef.min_feature_value = min(all_data)
            
            def predict(self, features):
                # sign( X.W + b)
                classification = np.sign(np.dot(np.array(features), self.w) + self.b)
                
                return classification

# %%
# starting with simple data:-
data_dict = {-1:np.array([[1,7],
                         [2,8],
                         [3,8]]),
             1:np.array([[5,1],
                        [6,-1],
                        [7,3]])}
